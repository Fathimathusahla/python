# %%
a=int(input("Enter a number:"))
if a%7==0:
    print("the number is divisible by 5")
else:
    print("the number is not divisible by 5")
# Out:
# Enter a number:14
# the number is divisible by 5

# %%
ch=input("Enter the character:")
if ch in 'aeiouAEIOU':
    print("it is a vowel")
else:
    print("it is not a vowel")
# Out:
# Enter the character:A
# it is a vowel

# %%
age=int(input("Enter your age:"))
if age>=18:
    print("Eligible for applying Driving licence")
else:
    print("Not eligible for applying Driving licence")
# Out:
# Enter your age:45
# Eligible for applying Driving licence

# %%
str1=(input("Enter the first string:"))
str2=(input("enter the second srting:"))
if str1==str2:
    print("Two strings are equal")
else:
    print("Two strings are not equal")
# Out:
# Enter the first string:hello
# enter the second srting:world
# Two strings are not equal

# %%
amount=int(input("Enter the amount:"))
if amount>5000:
    print("customer is eligible for a discound")
else:
    print("Not eligible for a discount")
# Out:
# Enter the amount:6000
# customer is eligible for a discound

# %%
n=int(input("Enter a number:"))
if n in range(10,100):
    print("the number is lies between 10 and 100")
else:
     print("the number is not lies between 10 and 100")
# Out:
# Enter a number:60
# the number is lies between 10 and 100

# %%
attendence=float(input("Enter the attendence percentage:"))
if attendence>=75:
    print("Eligible to attend the exam")
else:
    print("not eligible to attend the exam")
# Out:
# Enter the attendence percentage:75
# Eligible to attend the exam

# %%
a=input("enter an alphabhet:")
if a.isupper():
    print("Uppercase letter")
else:
    print("Lowercase letter")
# Out:
# enter an alphabhet:D
# Uppercase letter

# %%
n=int(input("Enter a number:"))
if n>=100 and n<=999:
    print("it is a Three-digit number")
else:
    print("it is not a three-digit number")
# Out:
# Enter a number:899
# it is a Three-digit number

# %%
data=float(input("enter the amount of data in GB:"))
if data<2:
    print("Low usage")
elif data<=5:
    print("Moderate usage")
else:
    print("High usage")
# Out:
# enter the amount of data in GB:3.5
# Moderate usage
