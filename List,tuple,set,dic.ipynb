# %%
marks=[45,67,90,65,99]
print("first mark:",marks[0])
# Out:
# first mark: 45

# %%
ls=[23,10,30,50]
print(ls.append(60))
# Out:
# None

# %%
ls=[23,10,30,50]
ls.append(60)
print(ls)
# Out:
# [23, 10, 30, 50, 60]

# %%
num=(1,2,3,4,5)
print(num[3])
# Out:
# 4

# %%
set={67,45,34,23,12}
print(set)
# Out:
# {34, 67, 23, 12, 45}

# %%
student={"name":"sahla","age":22,"mark":85}
print(student["name"])
# Out:
# sahla

# %%
string="student"
print(string[0])
print(string[6])
# Out:
# s
# t
