# %%
print("hello")
# Out:
# hello

# %%
print(10+20)
# Out:
# 30

# %%
name="john"
print(name)
print("name:"+name)
# Out:
# john
# name:john

# %%
a=20
b=70
c=a+b
print(c)
# Out:
# 90

# %%
age=22
mark=70.5
name="anu"
passed="true"
print(type(age))
print(type(mark))
print(type(name))
print(type(passed))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
